# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
import numpy as np

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

# %%
webpage=requests.get('https://www.goodreads.com/shelf/show/thriller?page=1').text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
for i in soup.find_all('h1'):
  print(i.text.strip())
# Out:
# Thriller Books

# %%
len(soup.find_all('a', class_='bookTitle'))
# Out:
# 50

# %%
len(soup.find_all('a', class_='authorName'))
# Out:
# 50

# %%
company = soup.find_all('div', class_ = 'elementList')

# %%
len(company)
# Out:
# 52

# %%
bookName = []
authorName = []
avg_rating = []
num_ratings = []
published_year = []

for i in company:
    book_title_element = i.find('a', class_='bookTitle')
    author_name_element = i.find('a', class_='authorName')
    rating_element = i.find('span', class_='greyText smallText')

    if book_title_element is not None:
        bookName.append(book_title_element.text.strip())
    else:
        bookName.append("N/A")

    if author_name_element is not None:
        authorName.append(author_name_element.text.strip())
    else:
        authorName.append("N/A")

    if rating_element is not None:

        rating_text = rating_element.text.strip()
        avg_match = re.search(r'avg rating (\d+\.\d+)', rating_text)
        num_match = re.search(r'(\d+,\d+) ratings', rating_text)
        year_match = re.search(r'published (\d{4})', rating_text)

        avg_rating.append(avg_match.group(1) if avg_match else "N/A")
        num_ratings.append(num_match.group(1).replace(',', '') if num_match else "N/A")
        published_year.append(year_match.group(1) if year_match else "N/A")
    else:
        avg_rating.append("N/A")
        num_ratings.append("N/A")
        published_year.append("N/A")

# %%
df = pd.DataFrame({'bookName':bookName,
                   'authorName':authorName,
                   'avg_rating':avg_rating,
                   'num_ratings':num_ratings,
                   'published_year':published_year})

# %%
bookName
# Out:
# ['Gone Girl (Paperback)',
#  'The Silent Patient (Hardcover)',
#  'The Girl on the Train (Hardcover)',
#  'The Da Vinci Code (Robert Langdon, #2)',
#  'The Girl with the Dragon Tattoo (Millennium, #1)',
#  'Verity (ebook)',
#  'Angels & Demons (Robert Langdon, #1)',
#  'Sharp Objects (Paperback)',
#  'The Woman in the Window (Kindle Edition)',
#  'The Girl Who Played with Fire (Millennium, #2)',
#  'The Guest List (Kindle Edition)',
#  "The Girl Who Kicked the Hornet's Nest (Millennium, #3)",
#  'Dark Places (Hardcover)',
#  'The Lost Symbol (Robert Langdon, #3)',
#  "A Good Girl's Guide to Murder (A Good Girl's Guide to Murder, #1)",
#  'Behind Closed Doors (Hardcover)',
#  'Inferno (Robert Langdon, #4)',
#  'Dark Matter (Hardcover)',
#  'And Then There Were None (Paperback)',
#  'The Woman in Cabin 10 (Hardcover)',
#  'Deception Point (Mass Market Paperback)',
#  'Digital Fortress (Paperback)',
#  'Lock Every Door (ebook)',
#  'Pretty Girls (Paperback)',
#  'Then She Was Gone (Hardcover)',
#  'The Silence of the Lambs  (Hannibal Lecter, #2)',
#  'Rock Paper Scissors (Hardcover)',
#  'You (You, #1)',
#  'Final Girls (Hardcover)',
#  'One of Us Is Lying (One of Us is Lying, #1)',
#  'The Turn of the Key (Hardcover)',
#  'Before I Go to Sleep (Hardcover)',
#  'The Shining (The Shining, #1)',
#  'The Housemaid (The Housemaid, #1)',
#  'The Couple Next Door (Hardcover)',
#  'Misery (Paperback)',
#  'Jurassic Park (Jurassic Park, #1)',
#  'The Maidens (Hardcover)',
#  'Killing Floor (Jack Reacher, #1)',
#  'A Flicker in the Dark (Hardcover)',
#  'The Paris Apartment (Hardcover)',
#  'The Family Upstairs (The Family Upstairs, #1)',
#  'Red Dragon (Hannibal Lecter, #1)',
#  'Home Before Dark (Hardcover)',
#  'No Exit (Kindle Edition)',
#  'The Kind Worth Killing (Henry Kimball/Lily Kintner, #1)',
#  'The 7 1/2 Deaths of Evelyn Hardcastle (Hardcover)',
#  'Into the Water (Hardcover)',
#  'In a Dark, Dark Wood (Paperback)',
#  'The Wife Between Us (Hardcover)',
#  'N/A',
#  'N/A']

# %%
authorName
# Out:
# ['Gillian Flynn',
#  'Alex Michaelides',
#  'Paula Hawkins',
#  'Dan Brown',
#  'Stieg Larsson',
#  'Colleen Hoover',
#  'Dan Brown',
#  'Gillian Flynn',
#  'A.J. Finn',
#  'Stieg Larsson',
#  'Lucy Foley',
#  'Stieg Larsson',
#  'Gillian Flynn',
#  'Dan Brown',
#  'Holly  Jackson',
#  'B.A. Paris',
#  'Dan Brown',
#  'Blake Crouch',
#  'Agatha Christie',
#  'Ruth Ware',
#  'Dan Brown',
#  'Dan Brown',
#  'Riley Sager',
#  'Karin Slaughter',
#  'Lisa Jewell',
#  'Thomas  Harris',
#  'Alice Feeney',
#  'Caroline Kepnes',
#  'Riley Sager',
#  'Karen M. McManus',
#  'Ruth Ware',
#  'S.J. Watson',
#  'Stephen King',
#  'Freida McFadden',
#  'Shari Lapena',
#  'Stephen King',
#  'Michael Crichton',
#  'Alex Michaelides',
#  'Lee Child',
#  'Stacy Willingham',
#  'Lucy Foley',
#  'Lisa Jewell',
#  'Thomas  Harris',
#  'Riley Sager',
#  'Taylor  Adams',
#  'Peter  Swanson',
#  'Stuart Turton',
#  'Paula Hawkins',
#  'Ruth Ware',
#  'Greer Hendricks',
#  'N/A',
#  'N/A']

# %%
avg_rating
# Out:
# ['4.12',
#  '4.18',
#  '3.96',
#  '3.91',
#  '4.16',
#  '4.34',
#  '3.93',
#  '4.01',
#  '3.95',
#  '4.25',
#  '3.83',
#  '4.23',
#  '3.95',
#  '3.74',
#  '4.34',
#  '3.98',
#  '3.88',
#  '4.13',
#  '4.28',
#  '3.74',
#  '3.75',
#  '3.69',
#  '3.91',
#  '4.04',
#  '4.06',
#  '4.24',
#  '3.94',
#  '3.95',
#  '3.84',
#  '3.95',
#  '3.93',
#  '3.90',
#  '4.26',
#  '4.34',
#  '3.81',
#  '4.21',
#  '4.09',
#  '3.62',
#  '4.07',
#  '4.00',
#  '3.67',
#  '3.97',
#  '4.05',
#  '4.08',
#  '4.02',
#  '4.01',
#  '3.84',
#  '3.59',
#  '3.72',
#  '3.85',
#  'N/A',
#  'N/A']

# %%
num_ratings
# Out:
# ['960518',
#  '794971',
#  '815119',
#  '294515',
#  '090860',
#  '255392',
#  '121891',
#  '978990',
#  '741664',
#  '906208',
#  '891282',
#  '722547',
#  '723747',
#  '597269',
#  '815006',
#  '541526',
#  '539973',
#  '445377',
#  '277481',
#  '577004',
#  '660103',
#  '626716',
#  '185912',
#  '319663',
#  '584320',
#  '537666',
#  '349034',
#  '233325',
#  '169421',
#  '768807',
#  '260613',
#  '332919',
#  '428583',
#  '617598',
#  '545393',
#  '662978',
#  '933347',
#  '292758',
#  '307802',
#  '308679',
#  '439963',
#  '361705',
#  '323830',
#  '171427',
#  '142263',
#  '168556',
#  '336481',
#  '376173',
#  '333421',
#  '368533',
#  'N/A',
#  'N/A']

# %%
published_year
# Out:
# ['2012',
#  '2019',
#  '2015',
#  '2003',
#  '2005',
#  '2018',
#  '2000',
#  '2006',
#  '2018',
#  '2006',
#  '2020',
#  '2007',
#  '2009',
#  '2009',
#  '2019',
#  '2016',
#  '2013',
#  '2016',
#  '1939',
#  '2016',
#  '2001',
#  '1998',
#  '2019',
#  '2015',
#  '2017',
#  '1988',
#  '2021',
#  '2014',
#  '2017',
#  '2017',
#  '2019',
#  '2011',
#  '1977',
#  '2022',
#  '2016',
#  '1987',
#  '1990',
#  '2021',
#  '1997',
#  '2022',
#  '2022',
#  '2019',
#  '1981',
#  '2020',
#  '2018',
#  '2015',
#  '2018',
#  '2017',
#  '2015',
#  '2018',
#  'N/A',
#  'N/A']

# %%
df
# Out:
#                                              bookName        authorName  \
# 0                               Gone Girl (Paperback)     Gillian Flynn
# 1                      The Silent Patient (Hardcover)  Alex Michaelides
# 2                   The Girl on the Train (Hardcover)     Paula Hawkins
# 3              The Da Vinci Code (Robert Langdon, #2)         Dan Brown
# 4    The Girl with the Dragon Tattoo (Millennium, #1)     Stieg Larsson
# 5                                      Verity (ebook)    Colleen Hoover
# 6                Angels & Demons (Robert Langdon, #1)         Dan Brown
# 7                           Sharp Objects (Paperback)     Gillian Flynn
# 8            The Woman in the Window (Kindle Edition)         A.J. Finn
# 9      The Girl Who Played with Fire (Millennium, #2)     Stieg Larsson
# 10                    The Guest List (Kindle Edition)        Lucy Foley
# 11  The Girl Who Kicked the Hornet's Nest (Millenn...     Stieg Larsson
# 12                            Dark Places (Hardcover)     Gillian Flynn
# 13               The Lost Symbol (Robert Langdon, #3)         Dan Brown
# 14  A Good Girl's Guide to Murder (A Good Girl's G...    Holly  Jackson
# 15                    Behind Closed Doors (Hardcover)        B.A. Paris
# 16                       Inferno (Robert Langdon, #4)         Dan Brown
# 17                            Dark Matter (Hardcover)      Blake Crouch
# 18               And Then There Were None (Paperback)   Agatha Christie
# 19                  The Woman in Cabin 10 (Hardcover)         Ruth Ware
# 20            Deception Point (Mass Market Paperback)         Dan Brown
# 21                       Digital Fortress (Paperback)         Dan Brown
# 22                            Lock Every Door (ebook)       Riley Sager
# 23                           Pretty Girls (Paperback)   Karin Slaughter
# 24                      Then She Was Gone (Hardcover)       Lisa Jewell
# 25    The Silence of the Lambs  (Hannibal Lecter, #2)    Thomas  Harris
# 26                    Rock Paper Scissors (Hardcover)      Alice Feeney
# 27                                      You (You, #1)   Caroline Kepnes
# 28                            Final Girls (Hardcover)       Riley Sager
# 29        One of Us Is Lying (One of Us is Lying, #1)  Karen M. McManus
# 30                    The Turn of the Key (Hardcover)         Ruth Ware
# 31                   Before I Go to Sleep (Hardcover)       S.J. Watson
# 32                      The Shining (The Shining, #1)      Stephen King
# 33                  The Housemaid (The Housemaid, #1)   Freida McFadden
# 34                   The Couple Next Door (Hardcover)      Shari Lapena
# 35                                 Misery (Paperback)      Stephen King
# 36                  Jurassic Park (Jurassic Park, #1)  Michael Crichton
# 37                            The Maidens (Hardcover)  Alex Michaelides
# 38                   Killing Floor (Jack Reacher, #1)         Lee Child
# 39                  A Flicker in the Dark (Hardcover)  Stacy Willingham
# 40                    The Paris Apartment (Hardcover)        Lucy Foley
# 41      The Family Upstairs (The Family Upstairs, #1)       Lisa Jewell
# 42                   Red Dragon (Hannibal Lecter, #1)    Thomas  Harris
# 43                       Home Before Dark (Hardcover)       Riley Sager
# 44                           No Exit (Kindle Edition)     Taylor  Adams
# 45  The Kind Worth Killing (Henry Kimball/Lily Kin...    Peter  Swanson
# 46  The 7 1/2 Deaths of Evelyn Hardcastle (Hardcover)     Stuart Turton
# 47                         Into the Water (Hardcover)     Paula Hawkins
# 48                   In a Dark, Dark Wood (Paperback)         Ruth Ware
# 49                    The Wife Between Us (Hardcover)   Greer Hendricks
# 50                                                N/A               N/A
# 51                                                N/A               N/A
#
#    avg_rating num_ratings published_year
# 0        4.12      960518           2012
# 1        4.18      794971           2019
# 2        3.96      815119           2015
# 3        3.91      294515           2003
# 4        4.16      090860           2005
# 5        4.34      255392           2018
# 6        3.93      121891           2000
# 7        4.01      978990           2006
# 8        3.95      741664           2018
# 9        4.25      906208           2006
# 10       3.83      891282           2020
# 11       4.23      722547           2007
# 12       3.95      723747           2009
# 13       3.74      597269           2009
# 14       4.34      815006           2019
# 15       3.98      541526           2016
# 16       3.88      539973           2013
# 17       4.13      445377           2016
# 18       4.28      277481           1939
# 19       3.74      577004           2016
# 20       3.75      660103           2001
# 21       3.69      626716           1998
# 22       3.91      185912           2019
# 23       4.04      319663           2015
# 24       4.06      584320           2017
# 25       4.24      537666           1988
# 26       3.94      349034           2021
# 27       3.95      233325           2014
# 28       3.84      169421           2017
# 29       3.95      768807           2017
# 30       3.93      260613           2019
# 31       3.90      332919           2011
# 32       4.26      428583           1977
# 33       4.34      617598           2022
# 34       3.81      545393           2016
# 35       4.21      662978           1987
# 36       4.09      933347           1990
# 37       3.62      292758           2021
# 38       4.07      307802           1997
# 39       4.00      308679           2022
# 40       3.67      439963           2022
# 41       3.97      361705           2019
# 42       4.05      323830           1981
# 43       4.08      171427           2020
# 44       4.02      142263           2018
# 45       4.01      168556           2015
# 46       3.84      336481           2018
# 47       3.59      376173           2017
# 48       3.72      333421           2015
# 49       3.85      368533           2018
# 50        N/A         N/A            N/A
# 51        N/A         N/A            N/A

# %%
df.shape
# Out:
# (52, 5)

# %%
df = df[df['bookName'] != 'N/A']

# %%
df
# Out:
#                                              bookName        authorName  \
# 0                               Gone Girl (Paperback)     Gillian Flynn
# 1                      The Silent Patient (Hardcover)  Alex Michaelides
# 2                   The Girl on the Train (Hardcover)     Paula Hawkins
# 3              The Da Vinci Code (Robert Langdon, #2)         Dan Brown
# 4    The Girl with the Dragon Tattoo (Millennium, #1)     Stieg Larsson
# 5                                      Verity (ebook)    Colleen Hoover
# 6                Angels & Demons (Robert Langdon, #1)         Dan Brown
# 7                           Sharp Objects (Paperback)     Gillian Flynn
# 8            The Woman in the Window (Kindle Edition)         A.J. Finn
# 9      The Girl Who Played with Fire (Millennium, #2)     Stieg Larsson
# 10                    The Guest List (Kindle Edition)        Lucy Foley
# 11  The Girl Who Kicked the Hornet's Nest (Millenn...     Stieg Larsson
# 12                            Dark Places (Hardcover)     Gillian Flynn
# 13               The Lost Symbol (Robert Langdon, #3)         Dan Brown
# 14  A Good Girl's Guide to Murder (A Good Girl's G...    Holly  Jackson
# 15                    Behind Closed Doors (Hardcover)        B.A. Paris
# 16                       Inferno (Robert Langdon, #4)         Dan Brown
# 17                            Dark Matter (Hardcover)      Blake Crouch
# 18               And Then There Were None (Paperback)   Agatha Christie
# 19                  The Woman in Cabin 10 (Hardcover)         Ruth Ware
# 20            Deception Point (Mass Market Paperback)         Dan Brown
# 21                       Digital Fortress (Paperback)         Dan Brown
# 22                            Lock Every Door (ebook)       Riley Sager
# 23                           Pretty Girls (Paperback)   Karin Slaughter
# 24                      Then She Was Gone (Hardcover)       Lisa Jewell
# 25    The Silence of the Lambs  (Hannibal Lecter, #2)    Thomas  Harris
# 26                    Rock Paper Scissors (Hardcover)      Alice Feeney
# 27                                      You (You, #1)   Caroline Kepnes
# 28                            Final Girls (Hardcover)       Riley Sager
# 29        One of Us Is Lying (One of Us is Lying, #1)  Karen M. McManus
# 30                    The Turn of the Key (Hardcover)         Ruth Ware
# 31                   Before I Go to Sleep (Hardcover)       S.J. Watson
# 32                      The Shining (The Shining, #1)      Stephen King
# 33                  The Housemaid (The Housemaid, #1)   Freida McFadden
# 34                   The Couple Next Door (Hardcover)      Shari Lapena
# 35                                 Misery (Paperback)      Stephen King
# 36                  Jurassic Park (Jurassic Park, #1)  Michael Crichton
# 37                            The Maidens (Hardcover)  Alex Michaelides
# 38                   Killing Floor (Jack Reacher, #1)         Lee Child
# 39                  A Flicker in the Dark (Hardcover)  Stacy Willingham
# 40                    The Paris Apartment (Hardcover)        Lucy Foley
# 41      The Family Upstairs (The Family Upstairs, #1)       Lisa Jewell
# 42                   Red Dragon (Hannibal Lecter, #1)    Thomas  Harris
# 43                       Home Before Dark (Hardcover)       Riley Sager
# 44                           No Exit (Kindle Edition)     Taylor  Adams
# 45  The Kind Worth Killing (Henry Kimball/Lily Kin...    Peter  Swanson
# 46  The 7 1/2 Deaths of Evelyn Hardcastle (Hardcover)     Stuart Turton
# 47                         Into the Water (Hardcover)     Paula Hawkins
# 48                   In a Dark, Dark Wood (Paperback)         Ruth Ware
# 49                    The Wife Between Us (Hardcover)   Greer Hendricks
#
#    avg_rating num_ratings published_year
# 0        4.12      960518           2012
# 1        4.18      794971           2019
# 2        3.96      815119           2015
# 3        3.91      294515           2003
# 4        4.16      090860           2005
# 5        4.34      255392           2018
# 6        3.93      121891           2000
# 7        4.01      978990           2006
# 8        3.95      741664           2018
# 9        4.25      906208           2006
# 10       3.83      891282           2020
# 11       4.23      722547           2007
# 12       3.95      723747           2009
# 13       3.74      597269           2009
# 14       4.34      815006           2019
# 15       3.98      541526           2016
# 16       3.88      539973           2013
# 17       4.13      445377           2016
# 18       4.28      277481           1939
# 19       3.74      577004           2016
# 20       3.75      660103           2001
# 21       3.69      626716           1998
# 22       3.91      185912           2019
# 23       4.04      319663           2015
# 24       4.06      584320           2017
# 25       4.24      537666           1988
# 26       3.94      349034           2021
# 27       3.95      233325           2014
# 28       3.84      169421           2017
# 29       3.95      768807           2017
# 30       3.93      260613           2019
# 31       3.90      332919           2011
# 32       4.26      428583           1977
# 33       4.34      617598           2022
# 34       3.81      545393           2016
# 35       4.21      662978           1987
# 36       4.09      933347           1990
# 37       3.62      292758           2021
# 38       4.07      307802           1997
# 39       4.00      308679           2022
# 40       3.67      439963           2022
# 41       3.97      361705           2019
# 42       4.05      323830           1981
# 43       4.08      171427           2020
# 44       4.02      142263           2018
# 45       4.01      168556           2015
# 46       3.84      336481           2018
# 47       3.59      376173           2017
# 48       3.72      333421           2015
# 49       3.85      368533           2018

# %%
final = pd.DataFrame()
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
}


num_pages = 25 #max no. of pages

for page_num in range(1, num_pages + 1):
    url = f'https://www.goodreads.com/shelf/show/thriller?page={page_num}'
    webpage = requests.get(url, headers=headers).text

    soup = BeautifulSoup(webpage, 'lxml')

    bookName = []
    authorName = []
    avg_rating = []
    num_ratings = []
    published_year = []

    for i in company:
        book_title_element = i.find('a', class_='bookTitle')
        author_name_element = i.find('a', class_='authorName')
        rating_element = i.find('span', class_='greyText smallText')

        if book_title_element is not None:
            bookName.append(book_title_element.text.strip())
        else:
            bookName.append("N/A")

        if author_name_element is not None:
            authorName.append(author_name_element.text.strip())
        else:
            authorName.append("N/A")

        if rating_element is not None:
            rating_text = rating_element.text.strip()
            avg_match = re.search(r'avg rating (\d+\.\d+)', rating_text)
            num_match = re.search(r'(\d+,\d+) ratings', rating_text)
            year_match = re.search(r'published (\d{4})', rating_text)

            avg_rating.append(avg_match.group(1) if avg_match else "N/A")
            num_ratings.append(num_match.group(1).replace(',', '') if num_match else "N/A")
            published_year.append(year_match.group(1) if year_match else "N/A")
        else:
            avg_rating.append("N/A")
            num_ratings.append("N/A")
            published_year.append("N/A")

    df = pd.DataFrame({'bookName': bookName,
                       'authorName': authorName,
                       'avg_rating': avg_rating,
                       'num_ratings': num_ratings,
                       'published_year': published_year})

    final = final.append(df, ignore_index=True)

final.to_csv('goodreads_thriller_books.csv', index=False)
# Out:
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)
# <ipython-input-21-e8efb0d8bcd7>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)

# %%
final=final.append(df,ignore_index=True)
# Out:
# <ipython-input-22-766fa86d9c0e>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)

# %%
df = df[df['bookName'] != 'N/A']

# %%
df.shape
# Out:
# (50, 5)

# %%
final.shape
# Out:
# (1352, 5)

# %%
df
# Out:
#                                              bookName        authorName  \
# 0                               Gone Girl (Paperback)     Gillian Flynn
# 1                      The Silent Patient (Hardcover)  Alex Michaelides
# 2                   The Girl on the Train (Hardcover)     Paula Hawkins
# 3              The Da Vinci Code (Robert Langdon, #2)         Dan Brown
# 4    The Girl with the Dragon Tattoo (Millennium, #1)     Stieg Larsson
# 5                                      Verity (ebook)    Colleen Hoover
# 6                Angels & Demons (Robert Langdon, #1)         Dan Brown
# 7                           Sharp Objects (Paperback)     Gillian Flynn
# 8            The Woman in the Window (Kindle Edition)         A.J. Finn
# 9      The Girl Who Played with Fire (Millennium, #2)     Stieg Larsson
# 10                    The Guest List (Kindle Edition)        Lucy Foley
# 11  The Girl Who Kicked the Hornet's Nest (Millenn...     Stieg Larsson
# 12                            Dark Places (Hardcover)     Gillian Flynn
# 13               The Lost Symbol (Robert Langdon, #3)         Dan Brown
# 14  A Good Girl's Guide to Murder (A Good Girl's G...    Holly  Jackson
# 15                    Behind Closed Doors (Hardcover)        B.A. Paris
# 16                       Inferno (Robert Langdon, #4)         Dan Brown
# 17                            Dark Matter (Hardcover)      Blake Crouch
# 18               And Then There Were None (Paperback)   Agatha Christie
# 19                  The Woman in Cabin 10 (Hardcover)         Ruth Ware
# 20            Deception Point (Mass Market Paperback)         Dan Brown
# 21                       Digital Fortress (Paperback)         Dan Brown
# 22                            Lock Every Door (ebook)       Riley Sager
# 23                           Pretty Girls (Paperback)   Karin Slaughter
# 24                      Then She Was Gone (Hardcover)       Lisa Jewell
# 25    The Silence of the Lambs  (Hannibal Lecter, #2)    Thomas  Harris
# 26                    Rock Paper Scissors (Hardcover)      Alice Feeney
# 27                                      You (You, #1)   Caroline Kepnes
# 28                            Final Girls (Hardcover)       Riley Sager
# 29        One of Us Is Lying (One of Us is Lying, #1)  Karen M. McManus
# 30                    The Turn of the Key (Hardcover)         Ruth Ware
# 31                   Before I Go to Sleep (Hardcover)       S.J. Watson
# 32                      The Shining (The Shining, #1)      Stephen King
# 33                  The Housemaid (The Housemaid, #1)   Freida McFadden
# 34                   The Couple Next Door (Hardcover)      Shari Lapena
# 35                                 Misery (Paperback)      Stephen King
# 36                  Jurassic Park (Jurassic Park, #1)  Michael Crichton
# 37                            The Maidens (Hardcover)  Alex Michaelides
# 38                   Killing Floor (Jack Reacher, #1)         Lee Child
# 39                  A Flicker in the Dark (Hardcover)  Stacy Willingham
# 40                    The Paris Apartment (Hardcover)        Lucy Foley
# 41      The Family Upstairs (The Family Upstairs, #1)       Lisa Jewell
# 42                   Red Dragon (Hannibal Lecter, #1)    Thomas  Harris
# 43                       Home Before Dark (Hardcover)       Riley Sager
# 44                           No Exit (Kindle Edition)     Taylor  Adams
# 45  The Kind Worth Killing (Henry Kimball/Lily Kin...    Peter  Swanson
# 46  The 7 1/2 Deaths of Evelyn Hardcastle (Hardcover)     Stuart Turton
# 47                         Into the Water (Hardcover)     Paula Hawkins
# 48                   In a Dark, Dark Wood (Paperback)         Ruth Ware
# 49                    The Wife Between Us (Hardcover)   Greer Hendricks
#
#    avg_rating num_ratings published_year
# 0        4.12      960518           2012
# 1        4.18      794971           2019
# 2        3.96      815119           2015
# 3        3.91      294515           2003
# 4        4.16      090860           2005
# 5        4.34      255392           2018
# 6        3.93      121891           2000
# 7        4.01      978990           2006
# 8        3.95      741664           2018
# 9        4.25      906208           2006
# 10       3.83      891282           2020
# 11       4.23      722547           2007
# 12       3.95      723747           2009
# 13       3.74      597269           2009
# 14       4.34      815006           2019
# 15       3.98      541526           2016
# 16       3.88      539973           2013
# 17       4.13      445377           2016
# 18       4.28      277481           1939
# 19       3.74      577004           2016
# 20       3.75      660103           2001
# 21       3.69      626716           1998
# 22       3.91      185912           2019
# 23       4.04      319663           2015
# 24       4.06      584320           2017
# 25       4.24      537666           1988
# 26       3.94      349034           2021
# 27       3.95      233325           2014
# 28       3.84      169421           2017
# 29       3.95      768807           2017
# 30       3.93      260613           2019
# 31       3.90      332919           2011
# 32       4.26      428583           1977
# 33       4.34      617598           2022
# 34       3.81      545393           2016
# 35       4.21      662978           1987
# 36       4.09      933347           1990
# 37       3.62      292758           2021
# 38       4.07      307802           1997
# 39       4.00      308679           2022
# 40       3.67      439963           2022
# 41       3.97      361705           2019
# 42       4.05      323830           1981
# 43       4.08      171427           2020
# 44       4.02      142263           2018
# 45       4.01      168556           2015
# 46       3.84      336481           2018
# 47       3.59      376173           2017
# 48       3.72      333421           2015
# 49       3.85      368533           2018
